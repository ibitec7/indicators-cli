# %%
import polars as pl
import numpy as np
import yfinance as yf
import argparse

# %%
schema = {
    "Open": pl.Float32,
    "High": pl.Float32,
    "Low": pl.Float32,
    "Close": pl.Float32,
    "Volume": pl.UInt64,
    "Dividends": pl.Float32,
    "Stock Splits": pl.Float32
}

df = pl.from_pandas(yf.Ticker("AAPL").history(period="5y"), schema_overrides=schema).lazy()
# Out:
# $AAPL: possibly delisted; no price data found  (period=5y)

# %%
columns = df.collect_schema().names()
df = df.rename({old: new for old, new in zip(columns, [x.lower() for x in columns])})

# %%
df = df.with_columns(
    pl.col("close").rolling_mean(window_size=20).alias("sma_20")
)

# %%
df.with_columns(
    pl.col("close").ewm_mean(span=20).alias("ema_20")
)
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="466pt" height="262pt"
#  viewBox="0.00 0.00 466.00 262.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 258)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-258 462,-258 462,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="452,-254 6,-254 6,-218 452,-218 452,-254"/>
# <text text-anchor="middle" x="229" y="-232.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;close&quot;).ewm_mean().alias(&quot;ema_20&quot;)]</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="458,-182 0,-182 0,-146 458,-146 458,-182"/>
# <text text-anchor="middle" x="229" y="-160.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;close&quot;).rolling_mean().alias(&quot;sma_20&quot;)]</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M229,-217.7C229,-206.85 229,-192.92 229,-182.1"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="271,-110 187,-110 187,-74 271,-74 271,-110"/>
# <text text-anchor="middle" x="229" y="-88.3" font-family="Times,serif" font-size="14.00">RENAME</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M229,-145.7C229,-134.85 229,-120.92 229,-110.1"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="261.5,-38 196.5,-38 196.5,0 261.5,0 261.5,-38"/>
# <text text-anchor="middle" x="229" y="-22.8" font-family="Times,serif" font-size="14.00">TABLE</text>
# <text text-anchor="middle" x="229" y="-7.8" font-family="Times,serif" font-size="14.00">π */6</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M229,-73.81C229,-62.98 229,-49.01 229,-38.02"/>
# </g>
# </g>
# </svg>

# %%
macd_short, macd_long, macd_signal = 12, 26, 9

def macd(df, macd_short, macd_long, macd_signal):
    df = df.with_columns(
        (pl.col("close").ewm_mean(span=macd_short, adjust=False) - pl.col("close")\
            .ewm_mean(span=macd_long, adjust=False)).alias("macd")
    )

    df = df.with_columns(
        pl.col("macd").ewm_mean(span=macd_signal, adjust=False).alias("signal_line")
    )

    df = df.with_columns(
        (pl.col("macd") - pl.col("signal_line")).alias("macd_hist")
    )

    return df

df = macd(df=df, macd_long=macd_long, macd_short=macd_short, macd_signal=macd_signal)

# %%
def rsi(df, win):
    df = df.with_columns(
        pl.col("close").diff(1).alias("returns")
    )

    df = df.with_columns(
        (100 / (1 + (pl.when(pl.col("returns") > 0)
        .then(pl.col(returns)).otherwise(0).rolling_mean(window_size=win) \
            / pl.when(pl.col("returns") < 0).
            then(pl.col("returns")).otherwise(0).rolling_mean(window_size=win)))).alias("rsi")
    )

    return df

df = rsi(df=df, win=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 15
#       6     df = df.with_columns(
#       7         (100 / (1 + (pl.when(pl.col("returns") > 0)
#       8         .then(pl.col(returns)).otherwise(0).rolling_mean(window_size=win) \
#       9             / pl.when(pl.col("returns") < 0).
#      10             then(pl.col("returns")).otherwise(0).rolling_mean(window_size=win)))).alias("rsi")
#      11     )
#      13     return df
# ---> 15 df = rsi(df=df, win=20)
#
# Cell In[134], line 8, in rsi(df, win)
#       1 def rsi(df, win):
#       2     df = df.with_columns(
#       3         pl.col("close").diff(1).alias("returns")
#       4     )
#       6     df = df.with_columns(
#       7         (100 / (1 + (pl.when(pl.col("returns") > 0)
# ----> 8         .then(pl.col(returns)).otherwise(0).rolling_mean(window_size=win) \
#       9             / pl.when(pl.col("returns") < 0).
#      10             then(pl.col("returns")).otherwise(0).rolling_mean(window_size=win)))).alias("rsi")
#      11     )
#      13     return df
#
# NameError: name 'returns' is not defined

# %%
def bbands(df, win):
    df = df.with_columns(
        (pl.col("close").rolling_mean(window_size=win) - 2 * pl.col("close").rolling_std(window_size=win)).alias("lower")
    )
    
    df = df.with_columns(
        (pl.col("close").rolling_mean(window_size=win) + 2 * pl.col("close").rolling_std(window_size=win)).alias("lower")
    )

    return df

df = bbands(df, win=20)

# %%
query = """
    SELECT AVG(returns) OVER() AS mean_returns
    FROM df
"""

pl.sql(query)
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="1545pt" height="766pt"
#  viewBox="0.00 0.00 1545.00 766.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 762)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-762 1541,-762 1541,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="795.5,-758 741.5,-758 741.5,-722 795.5,-722 795.5,-758"/>
# <text text-anchor="middle" x="768.5" y="-736.3" font-family="Times,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="1137,-686 400,-686 400,-650 1137,-650 1137,-686"/>
# <text text-anchor="middle" x="768.5" y="-664.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;close&quot;).rolling_mean()) + ([(2.0) * (col(&quot;close&quot;).rolling_std())])].alias(&quot;lower&quot;)]</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M768.5,-721.7C768.5,-710.85 768.5,-696.92 768.5,-686.1"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="1133,-614 404,-614 404,-578 1133,-578 1133,-614"/>
# <text text-anchor="middle" x="768.5" y="-592.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;close&quot;).rolling_mean()) &#45; ([(2.0) * (col(&quot;close&quot;).rolling_std())])].alias(&quot;lower&quot;)]</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M768.5,-649.7C768.5,-638.85 768.5,-624.92 768.5,-614.1"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="1537,-542 0,-542 0,-506 1537,-506 1537,-542"/>
# <text text-anchor="middle" x="768.5" y="-520.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(100.0) / ([(1.0) + ([(col(&quot;returns&quot;).filter([([(col(&quot;returns&quot;)) &gt; (0.0)]) &amp; (dyn int: 0)]).rolling_mean()) / (col(&quot;returns&quot;).filter([([(col(&quot;returns&quot;)) &lt; (0.0)]) &amp; (dyn int: 0)]).rolling_mean())])])].alias(&quot;rsi&quot;)]</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M768.5,-577.7C768.5,-566.85 768.5,-552.92 768.5,-542.1"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="962.5,-470 574.5,-470 574.5,-434 962.5,-434 962.5,-470"/>
# <text text-anchor="middle" x="768.5" y="-448.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;close&quot;).diff().alias(&quot;returns&quot;)]</text>
# </g>
# <!-- p4&#45;&#45;p5 -->
# <g id="edge4" class="edge">
# <title>p4&#45;&#45;p5</title>
# <path fill="none" stroke="black" d="M768.5,-505.7C768.5,-494.85 768.5,-480.92 768.5,-470.1"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="1036.5,-398 500.5,-398 500.5,-362 1036.5,-362 1036.5,-398"/>
# <text text-anchor="middle" x="768.5" y="-376.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;macd&quot;)) &#45; (col(&quot;signal_line&quot;))].alias(&quot;macd_hist&quot;)]</text>
# </g>
# <!-- p5&#45;&#45;p6 -->
# <g id="edge5" class="edge">
# <title>p5&#45;&#45;p6</title>
# <path fill="none" stroke="black" d="M768.5,-433.7C768.5,-422.85 768.5,-408.92 768.5,-398.1"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="1003,-326 534,-326 534,-290 1003,-290 1003,-326"/>
# <text text-anchor="middle" x="768.5" y="-304.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;macd&quot;).ewm_mean().alias(&quot;signal_line&quot;)]</text>
# </g>
# <!-- p6&#45;&#45;p7 -->
# <g id="edge6" class="edge">
# <title>p6&#45;&#45;p7</title>
# <path fill="none" stroke="black" d="M768.5,-361.7C768.5,-350.85 768.5,-336.92 768.5,-326.1"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="1093,-254 444,-254 444,-218 1093,-218 1093,-254"/>
# <text text-anchor="middle" x="768.5" y="-232.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;close&quot;).ewm_mean()) &#45; (col(&quot;close&quot;).ewm_mean())].alias(&quot;macd&quot;)]</text>
# </g>
# <!-- p7&#45;&#45;p8 -->
# <g id="edge7" class="edge">
# <title>p7&#45;&#45;p8</title>
# <path fill="none" stroke="black" d="M768.5,-289.7C768.5,-278.85 768.5,-264.92 768.5,-254.1"/>
# </g>
# <!-- p9 -->
# <g id="node9" class="node">
# <title>p9</title>
# <polygon fill="none" stroke="black" points="997.5,-182 539.5,-182 539.5,-146 997.5,-146 997.5,-182"/>
# <text text-anchor="middle" x="768.5" y="-160.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [col(&quot;close&quot;).rolling_mean().alias(&quot;sma_20&quot;)]</text>
# </g>
# <!-- p8&#45;&#45;p9 -->
# <g id="edge8" class="edge">
# <title>p8&#45;&#45;p9</title>
# <path fill="none" stroke="black" d="M768.5,-217.7C768.5,-206.85 768.5,-192.92 768.5,-182.1"/>
# </g>
# <!-- p10 -->
# <g id="node10" class="node">
# <title>p10</title>
# <polygon fill="none" stroke="black" points="810.5,-110 726.5,-110 726.5,-74 810.5,-74 810.5,-110"/>
# <text text-anchor="middle" x="768.5" y="-88.3" font-family="Times,serif" font-size="14.00">RENAME</text>
# </g>
# <!-- p9&#45;&#45;p10 -->
# <g id="edge9" class="edge">
# <title>p9&#45;&#45;p10</title>
# <path fill="none" stroke="black" d="M768.5,-145.7C768.5,-134.85 768.5,-120.92 768.5,-110.1"/>
# </g>
# <!-- p11 -->
# <g id="node11" class="node">
# <title>p11</title>
# <polygon fill="none" stroke="black" points="801,-38 736,-38 736,0 801,0 801,-38"/>
# <text text-anchor="middle" x="768.5" y="-22.8" font-family="Times,serif" font-size="14.00">TABLE</text>
# <text text-anchor="middle" x="768.5" y="-7.8" font-family="Times,serif" font-size="14.00">π */7</text>
# </g>
# <!-- p10&#45;&#45;p11 -->
# <g id="edge10" class="edge">
# <title>p10&#45;&#45;p11</title>
# <path fill="none" stroke="black" d="M768.5,-73.81C768.5,-62.98 768.5,-49.01 768.5,-38.02"/>
# </g>
# </g>
# </svg>

# %%
df.collect(engine="cpu")
# Out:
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 df.collect(engine="cpu")
#
# File ~/anaconda3/lib/python3.12/site-packages/polars/lazyframe/frame.py:2065, in LazyFrame.collect(self, type_coercion, _type_check, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _check_order, _eager, **_kwargs)
#    2063 # Only for testing purposes
#    2064 callback = _kwargs.get("post_opt_callback", callback)
# -> 2065 return wrap_df(ldf.collect(callback))
#
# ShapeError: unable to add a column of length 0 to a DataFrame of height 1256
